# %%
# standard libraries
import statsmodels.api as sm
import pandas as pd
import numpy as np
import importlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import sys
import warnings
warnings.filterwarnings('ignore')

# our libraries
home_path = '/home/nahuel.statuto/p-values'
sys.path.insert(0, home_path)

import sfit as s_fit
import functions as fn

# %%
importlib.reload(fn)
importlib.reload(s_fit)
# Out:
# <module 'sfit' from '/home/nahuel.statuto/p-values/sfit.py'>

# %%
def one_dim(x,dim,pos):
    for i in range(dim):
        if i!=(pos+1):
            x[:,i]=0
    return x
    

coef = [0.15,0.01,0.1,0.1]
expp = 2.5
noise_mean = 0.0
noise_var = 0.01
noise = 0.001
    
def model(X):
    return 3+4*X[0]+X[0]*X[1]+3*np.power(X[2],2)+2*X[3]*X[4]+ np.random.normal(noise_mean,noise_var)
    #return coef[0]*abs(X[0]) + coef[1]*np.exp(expp*abs(X[1])) + coef[2]*np.power(abs(X[2]+abs(X[3])+noise),coef[3]) + np.random.normal(noise_mean,noise_var)

def model_logX(X):
    return coef[0]*abs(X[0]) + coef[1]*np.power(abs(X[1]),expp) + coef[2]*np.power(abs(X[2]+abs(X[3])+noise),coef[3]) + np.random.normal(noise_mean,noise_var)

def toy_model(X,model,pos=None):
    ''' 
    funtion that returns a list with the y values using the input "X" and the function "model". 
    
    X: list of vectors. [ [],...,[] ].
    model: function te be evaluated .
    pos: integer value lower or equal to lengh of the X vectors. If pos=i, then y=[0,...,y_i,...,0] will be all 
        zeros except for the "i" position.
    '''
    x = X.copy()
    N,dim = np.shape(x)
    y = np.asarray([])
    
    if pos is not None:
        x = np.delete(one_dim(x,dim,pos),0,1)
        dim -= 1
    
    for i in range(N):
        aux = model([x[i]+np.random.uniform(0,noise_var,(1,dim))][0][0])
        y = np.concatenate((y, aux ), axis=None)
        
    if pos is None:
        return (y-np.mean(y))/(np.var(y))
    return y

# %%
dim = 7
N = 1000
X = np.random.uniform(0,1,(N,dim))

y = toy_model(X,model)
#y2 = toy_model(X,model_logX)

# %%
variable_names = ['x'+str(j) for j in range(dim)]
X = sm.add_constant(X)
xname = variable_names
xname.insert(0,'const')

max_cores = 90
test_size = 0.25
beta_vec = [0.0] #np.arange(0.1e-3,2e-2,1e-3)
print('using {0} different beta values for the test'.format(len(beta_vec)))
k_folds = 10
n_runs = int(max_cores/k_folds)*k_folds
n_runs = 1#int(max_cores/k_folds)*k_folds
layers=[[20,10]]
# Out:
# using 1 different beta values for the test

# %%
plt.figure()
for i in range(dim):
    plt.scatter(toy_model(X,model,pos=i),y,label=variable_names[i+1]+' - model', alpha=0.5)
plt.legend()
#plt.xlim(-3,100)
#plt.ylim(0.1,1000)

# %%
# Train models
second_order_bool = True
res = fn.different_models(X, y, k_folds, n_runs=n_runs, layers=layers, beta_vec=beta_vec, variable_names=variable_names, second_order_bool=second_order_bool)
# Out:
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-10-05 10:41:23.567992: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:23.575785: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:24.799914: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:24.805980: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.002310: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.007191: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.008796: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.014911: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.066706: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.072746: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.139941: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.145892: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.146147: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.153212: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.171425: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.176751: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.178848: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.184528: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.229072: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.234875: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.243043: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.252896: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.343179: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.355057: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.412809: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.425133: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.443297: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.449024: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.532662: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.535440: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.540532: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.541767: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.546636: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.552726: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.554116: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.561026: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.641902: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.653757: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.656127: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.662158: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.669917: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.676968: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.792897: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.803917: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.842466: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.856199: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.856421: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.864973: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.896352: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.906162: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.944594: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.954159: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:25.965161: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:25.973376: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.073449: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.083481: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.155356: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.162035: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.163621: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.167596: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.174012: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.176970: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.186305: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.194694: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.211455: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.218973: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.227905: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.241475: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.250122: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.252268: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.254882: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.259839: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.261159: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.269934: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-10-05 10:41:26.270093: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.275668: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:41:26.278430: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# ...
# 	 95% confidence interval: [0.05 0.2 ]
# ------------------------------------------------
# Second-order non-significant variables: [2, 4, 5, 6, 7]
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Optimal beta found: 0.07481827642679217
# Summary of first-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# First-order significant variables:
# - Variable 1:
# 	 Median: 0.44
# 	 95% confidence interval: [0.34 0.56]
# - Variable 3:
# 	 Median: 0.28
# 	 95% confidence interval: [0.16 0.36]
# ------------------------------------------------
# First-order non-significant variables: [2, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# Second-order significant variables:
# ------------------------------------------------
# Second-order non-significant variables: [2, 4, 5, 6, 7]
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Optimal beta found: 0.07481827642679217
# Summary of first-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# First-order significant variables:
# - Variable 1:
# 	 Median: 0.53
# 	 95% confidence interval: [0.37 0.75]
# - Variable 3:
# 	 Median: 0.1
# 	 95% confidence interval: [0.04 0.2 ]
# ------------------------------------------------
# First-order non-significant variables: [2, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# Second-order significant variables:
# - Variable (2, 1):
# 	 Median: 0.03
# 	 95% confidence interval: [0.   0.06]
# - Variable (4, 1):
# 	 Median: 0.04
# 	 95% confidence interval: [0.04 0.06]
# - Variable (4, 5):
# 	 Median: 0.06
# 	 95% confidence interval: [0.04 0.09]
# - Variable (5, 1):
# 	 Median: 0.03
# 	 95% confidence interval: [0.02 0.05]
# - Variable (5, 4):
# 	 Median: 0.06
# 	 95% confidence interval: [0.04 0.09]
# - Variable (7, 1):
# 	 Median: 0.11
# 	 95% confidence interval: [0.07 0.14]
# ------------------------------------------------
# Second-order non-significant variables: [6]
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Optimal beta found: 0.07481827642679217
# Summary of first-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# First-order significant variables:
# - Variable 1:
# 	 Median: 0.16
# 	 95% confidence interval: [0.12 0.29]
# - Variable 3:
# 	 Median: 0.03
# 	 95% confidence interval: [0.01 0.23]
# ------------------------------------------------
# First-order non-significant variables: [2, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# Second-order significant variables:
# ------------------------------------------------
# Second-order non-significant variables: [2, 4, 5, 6, 7]
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Optimal beta found: 0.07481827642679217
# Summary of first-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# First-order significant variables:
# - Variable 1:
# 	 Median: 0.57
# 	 95% confidence interval: [0.48 0.72]
# - Variable 3:
# 	 Median: 0.17
# 	 95% confidence interval: [0.11 0.22]
# ------------------------------------------------
# First-order non-significant variables: [2, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# Second-order significant variables:
# - Variable (4, 5):
# 	 Median: 0.06
# 	 95% confidence interval: [0.03 0.12]
# - Variable (5, 1):
# 	 Median: 0.02
# 	 95% confidence interval: [0.   0.04]
# - Variable (5, 3):
# 	 Median: 0.04
# 	 95% confidence interval: [0.   0.07]
# - Variable (5, 4):
# 	 Median: 0.06
# 	 95% confidence interval: [0.03 0.12]
# ------------------------------------------------
# Second-order non-significant variables: [2, 6, 7]
# 4/4 [==============================] - 0s 4ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Optimal beta found: 0.07481827642679217
# Summary of first-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# First-order significant variables:
# - Variable 1:
# 	 Median: 0.47
# 	 95% confidence interval: [0.27 0.62]
# - Variable 3:
# 	 Median: 0.26
# 	 95% confidence interval: [0.15 0.47]
# ------------------------------------------------
# First-order non-significant variables: [2, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.07481827642679217
# ------------------------------------------------
# Second-order significant variables:
# - Variable (2, 1):
# 	 Median: 0.01
# 	 95% confidence interval: [0.   0.03]
# ------------------------------------------------
# Second-order non-significant variables: [4, 5, 6, 7]
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Computing with beta = 0.11222741464018826
# Optimal beta found: 0.11222741464018826
# Summary of first-order SFIT with beta = 0.11222741464018826
# ------------------------------------------------
# First-order significant variables:
# - Variable 1:
# 	 Median: 0.61
# 	 95% confidence interval: [0.39 0.67]
# - Variable 3:
# 	 Median: 0.11
# 	 95% confidence interval: [0.05 0.46]
# ------------------------------------------------
# First-order non-significant variables: [2, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.11222741464018826
# ------------------------------------------------
# Second-order significant variables:
# ------------------------------------------------
# Second-order non-significant variables: [2, 4, 5, 6, 7]
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# Compute optimal beta
# Computing with beta = 1.5000000000000002e-05
# Computing with beta = 2.2500000000000005e-05
# Computing with beta = 3.375000000000001e-05
# Computing with beta = 5.062500000000001e-05
# Computing with beta = 7.593750000000002e-05
# Computing with beta = 0.00011390625000000003
# Computing with beta = 0.00017085937500000006
# Computing with beta = 0.0002562890625000001
# Computing with beta = 0.00038443359375000017
# Computing with beta = 0.0005766503906250003
# Computing with beta = 0.0008649755859375004
# Computing with beta = 0.0012974633789062506
# Computing with beta = 0.0019461950683593758
# Computing with beta = 0.0029192926025390638
# Computing with beta = 0.004378938903808595
# Computing with beta = 0.006568408355712893
# Computing with beta = 0.009852612533569338
# Computing with beta = 0.014778918800354007
# Computing with beta = 0.02216837820053101
# Computing with beta = 0.033252567300796516
# Computing with beta = 0.04987885095119478
# Computing with beta = 0.07481827642679217
# Computing with beta = 0.11222741464018826
# Optimal beta found: 0.11222741464018826
# Summary of first-order SFIT with beta = 0.11222741464018826
# ------------------------------------------------
# First-order significant variables:
# ------------------------------------------------
# First-order non-significant variables: [1, 2, 3, 4, 5, 6, 7]
# ------------------------------------------------
# There are some significant second-order variables: recommended to run second-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# Summary of second-order SFIT with beta = 0.11222741464018826
# ------------------------------------------------
# Second-order significant variables:
# - Variable (1, 1):
# 	 Median: 0.1
# 	 95% confidence interval: [0.01 0.23]
# - Variable (1, 2):
# 	 Median: 0.1
# 	 95% confidence interval: [0.04 0.25]
# - Variable (1, 3):
# 	 Median: 0.4
# 	 95% confidence interval: [0.26 0.56]
# - Variable (1, 4):
# 	 Median: 0.14
# 	 95% confidence interval: [0.06 0.25]
# - Variable (1, 5):
# 	 Median: 0.09
# 	 95% confidence interval: [0.02 0.24]
# - Variable (1, 6):
# 	 Median: 0.11
# 	 95% confidence interval: [0.   0.19]
# - Variable (1, 7):
# 	 Median: 0.15
# 	 95% confidence interval: [0.05 0.29]
# - Variable (2, 1):
# 	 Median: 0.1
# 	 95% confidence interval: [0.04 0.25]
# - Variable (3, 1):
# 	 Median: 0.4
# 	 95% confidence interval: [0.26 0.56]
# - Variable (4, 1):
# 	 Median: 0.14
# 	 95% confidence interval: [0.06 0.25]
# - Variable (5, 1):
# 	 Median: 0.09
# 	 95% confidence interval: [0.02 0.24]
# - Variable (6, 1):
# 	 Median: 0.11
# 	 95% confidence interval: [0.   0.19]
# - Variable (7, 1):
# 	 Median: 0.15
# 	 95% confidence interval: [0.05 0.29]
# ------------------------------------------------
# Second-order non-significant variables: []
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# ['const', 'x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6']
# ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6']

# %%
## OLS summary
print('base_loss_linear: {}'.format(res[0][3]))
print(res[0][0].summary(xname=xname))

## NN histograms
for result in res[1:]:
    print('base_loss: {}'.format(result[3]))
    print('r2: {}'.format(round(result[2],3)))
    fn.plot_heat_map(result[0], result[1], beta_vec=beta_vec)
# Out:
# base_loss_linear: 0.010100991091149775
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     4666.
# Date:                Thu, 05 Oct 2023   Prob (F-statistic):               0.00
# Time:                        10:45:23   Log-Likelihood:                 878.62
# No. Observations:                1000   AIC:                            -1741.
# Df Residuals:                     992   BIC:                            -1702.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7541      0.015   -115.766      0.000      -1.784      -1.724
# x0             1.5635      0.011    143.597      0.000       1.542       1.585
# x1             0.1606      0.011     14.617      0.000       0.139       0.182
# x2             1.0357      0.011     95.973      0.000       1.014       1.057
# x3             0.3440      0.011     30.498      0.000       0.322       0.366
# x4             0.3615      0.011     32.916      0.000       0.340       0.383
# x5            -0.0005      0.011     -0.048      0.962      -0.023       0.022
# x6            -0.0181      0.011     -1.656      0.098      -0.040       0.003
# ==============================================================================
# Omnibus:                       19.839   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.340
# Skew:                           0.284   Prob(JB):                     0.000104
# Kurtosis:                       2.657   Cond. No.                         9.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# base_loss: 0.0017531910511068803
# r2: 0.996
# 1

# %%
plt.figure()
for i in range(dim):
    plt.scatter(toy_model(X,model,pos=i),y,label=variable_names[i+1]+' - model')
plt.legend()
# Out:
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are some significant third-order variables: recommended to run third-order SFIT.
# ------------------------------------------------
# ------------------------------------------------
#
# ------------------------------------------------
# There are no significant third-order variables.
# ------------------------------------------------
# ------------------------------------------------

# %%
res2 = fn.different_models(X, y2, k_folds, n_runs=n_runs, layers=layers, beta_vec=beta_vec, variable_names=variable_names, second_order_bool=False)
# Out:
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/nahuel.statuto/.conda/envs/hw_tf2.8/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-09-27 13:06:42.509374: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.515275: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:42.671447: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.686505: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:42.729946: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.736933: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:42.829480: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.836117: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.841296: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:42.843364: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:42.882177: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.903145: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:42.914140: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:42.925277: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.017264: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.025336: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.048493: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.056002: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.096892: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.104719: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.189628: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.198451: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.238212: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.246993: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.364057: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.372571: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# 2023-09-27 13:06:43.453908: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 13:06:43.462499: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 104. Tune using inter_op_parallelism_threads for best performance.
# ['const', 'x0', 'x1', 'x2', 'x3', 'x4']
# ['x0', 'x1', 'x2', 'x3', 'x4']

# %%
## OLS summary
print('base_loss_linear: {}'.format(res2[0][3]))
print(res2[0][0].summary(xname=xname))

## NN histograms
for result in res2[1:]:
    print('base_loss: {}'.format(result[3]))
    print('r2: {}'.format(round(result[2],3)))
    fn.plot_heat_map(result[0], result[1], beta_vec=beta_vec)
# Out:
# base_loss_linear: 139.7605482833804
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     166.0
# Date:                Wed, 27 Sep 2023   Prob (F-statistic):          5.90e-116
# Time:                        13:08:28   Log-Likelihood:                -2722.2
# No. Observations:                 700   AIC:                             5456.
# Df Residuals:                     694   BIC:                             5484.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -27.2032      1.822    -14.926      0.000     -30.781     -23.625
# x0            44.2926      1.559     28.404      0.000      41.231      47.354
# x1             4.9523      1.553      3.189      0.001       1.904       8.001
# x2             3.3607      1.584      2.122      0.034       0.252       6.470
# x3             3.0287      1.515      2.000      0.046       0.055       6.002
# x4            -0.3697      1.538     -0.240      0.810      -3.389       2.650
# ==============================================================================
# Omnibus:                        4.842   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                4.669
# Skew:                           0.183   Prob(JB):                       0.0969
# Kurtosis:                       3.162   Cond. No.                         8.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# base_loss: 144.67010142556245
# r2: 0.542
# 40

# %%
plt.figure()
for i in range(dim):
    plt.scatter(toy_model(X,model_logX,pos=i),y2,label=variable_names[i+1]+' - model_logX')
plt.legend()
#plt.xlim(-1,1)
